# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_audlt = pd.read_csv('adult.csv')
audlt_income = df_audlt['Income']

# %%
# 計算薪資平均值
mean_value = audlt_income.mean()
print("薪資平均值：")
print(mean_value)
# Out:
# 薪資平均值：
# 189778.36651208502

# %%
# 計算薪資標準差
std_value = audlt_income.std()
print("薪資標準差：")
print(std_value)
# Out:
# 薪資標準差：
# 105549.97769702233

# %%
plt.hist(audlt_income, bins=10, color='skyblue', edgecolor='black')
plt.title('Salary Distribution')
plt.xlabel('Salary')
plt.ylabel('Number of people')
plt.grid(True)
plt.legend(['Salary'])
plt.show()
